# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 1 | mount holly
# Processing Record 6 of Set 1 | mount isa
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | kankakee
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | sistranda
# Processing Record 13 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | bongor
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | minsk
# Processing Record 24 of Set 1 | nakhon phanom
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | jaicos
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | altamira
# Processing Record 29 of Set 1 | buraydah
# Processing Record 30 of Set 1 | ous
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | sassandra
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | collie
# Processing Record 36 of Set 1 | astana
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | niamey
# Processing Record 40 of Set 1 | slave lake
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | bismarck
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | ostersund
# Processing Record 45 of Set 1 | ixtapa
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | byron bay
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | umm kaddadah
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | marawi
# Processing Record 5 of Set 2 | vikulovo
# Processing Record 6 of Set 2 | chara
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 2 | colac
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | bossangoa
# Processing Record 15 of Set 2 | dunedin
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | margate
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | juliaca
# Processing Record 23 of Set 2 | erenhot
# Processing Record 24 of Set 2 | malibu
# Processing Record 25 of Set 2 | klimovo
# Processing Record 26 of Set 2 | rio gallegos
# Processing Record 27 of Set 2 | dzilam gonzalez
# Processing Record 28 of Set 2 | katobu
# Processing Record 29 of Set 2 | ayan
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | pombas
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | alice springs
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | igarka
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | cabedelo
# Processing Record 40 of Set 2 | half moon bay
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | marabba
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | durres
# Processing Record 47 of Set 2 | wamba
# Processing Record 48 of Set 2 | mehriz
# Processing Record 49 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | apucarana
# Processing Record 5 of Set 3 | fort nelson
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | nobres
# Processing Record 9 of Set 3 | cadillac
# Processing Record 10 of Set 3 | brewer
# Processing Record 11 of Set 3 | palaikastron
# Processing Record 12 of Set 3 | sorong
# Processing Record 13 of Set 3 | port augusta
# Processing Record 14 of Set 3 | pokosnoye
# Processing Record 15 of Set 3 | anadyr
# Processing Record 16 of Set 3 | great yarmouth
# Processing Record 17 of Set 3 | port macquarie
# Processing Record 18 of Set 3 | ballina
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | dondo
# Processing Record 21 of Set 3 | urumqi
# Processing Record 22 of Set 3 | mapimi
# Processing Record 23 of Set 3 | san ramon de la nueva oran
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | alofi
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | belmonte
# Processing Record 30 of Set 3 | farsund
# Processing Record 31 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 3 | inhambane
# Processing Record 33 of Set 3 | neuquen
# Processing Record 34 of Set 3 | hokitika
# Processing Record 35 of Set 3 | eregli
# Processing Record 36 of Set 3 | pitimbu
# Processing Record 37 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 3 | padang
# Processing Record 39 of Set 3 | srednekolymsk
# Processing Record 40 of Set 3 | asau
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | hobart
# Processing Record 43 of Set 3 | jabinyanah
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | malangwa
# Processing Record 47 of Set 3 | kyra
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | bogdana
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | vidim
# Processing Record 2 of Set 4 | algiers
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | hovd
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | lewiston
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | lazaro cardenas
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | tanggulangin
# Processing Record 11 of Set 4 | hachinohe
# Processing Record 12 of Set 4 | moindou
# Processing Record 13 of Set 4 | santa maria
# Processing Record 14 of Set 4 | pindi gheb
# Processing Record 15 of Set 4 | teguldet
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | peleduy
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | beloha
# Processing Record 20 of Set 4 | dalnegorsk
# Processing Record 21 of Set 4 | mao
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 4 | constitucion
# Processing Record 25 of Set 4 | muli
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | beaverlodge
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | grand gaube
# Processing Record 32 of Set 4 | nautla
# Processing Record 33 of Set 4 | anloga
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | parkes
# Processing Record 37 of Set 4 | guerrero negro
# Processing Record 38 of Set 4 | kanniyakumari
# Processing Record 39 of Set 4 | fairbanks
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | cayenne
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 46 of Set 4 | victor harbor
# Processing Record 47 of Set 4 | japura
# Processing Record 48 of Set 4 | mamallapuram
# Processing Record 49 of Set 4 | port blair
# Processing Record 50 of Set 4 | bafoulabe
# Processing Record 1 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 5 | filingue
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | severo-kurilsk
# Processing Record 6 of Set 5 | erzin
# Processing Record 7 of Set 5 | pocoes
# Processing Record 8 of Set 5 | carutapera
# Processing Record 9 of Set 5 | darhan
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | jalu
# Processing Record 15 of Set 5 | rosarito
# Processing Record 16 of Set 5 | peniche
# Processing Record 17 of Set 5 | vilyuysk
# Processing Record 18 of Set 5 | rjukan
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | havre
# Processing Record 23 of Set 5 | narasannapeta
# Processing Record 24 of Set 5 | morrope
# Processing Record 25 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | ust-maya
# Processing Record 29 of Set 5 | harlingen
# Processing Record 30 of Set 5 | novki
# Processing Record 31 of Set 5 | zapolyarnyy
# Processing Record 32 of Set 5 | natal
# Processing Record 33 of Set 5 | boyolangu
# Processing Record 34 of Set 5 | miyako
# Processing Record 35 of Set 5 | miles city
# Processing Record 36 of Set 5 | batemans bay
# Processing Record 37 of Set 5 | deputatskiy
# Processing Record 38 of Set 5 | puksoozero
# Processing Record 39 of Set 5 | tessalit
# Processing Record 40 of Set 5 | scarborough
# Processing Record 41 of Set 5 | ambilobe
# Processing Record 42 of Set 5 | lafia
# Processing Record 43 of Set 5 | plainview
# Processing Record 44 of Set 5 | port said
# Processing Record 45 of Set 5 | kikuyu
# Processing Record 46 of Set 5 | ventspils
# Processing Record 47 of Set 5 | tiarei
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | takikawa
# Processing Record 50 of Set 5 | carbonia
# Processing Record 1 of Set 6 | murgab
# Processing Record 2 of Set 6 | yerbogachen
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | tacuarembo
# Processing Record 6 of Set 6 | te anau
# Processing Record 7 of Set 6 | sal rei
# Processing Record 8 of Set 6 | camargo
# Processing Record 9 of Set 6 | phalombe
# Processing Record 10 of Set 6 | zorritos
# Processing Record 11 of Set 6 | manyana
# Processing Record 12 of Set 6 | pangai
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | sangar
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | khani
# Processing Record 17 of Set 6 | port alfred
# Processing Record 18 of Set 6 | fengcheng
# Processing Record 19 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | keti bandar
# Processing Record 23 of Set 6 | bodden town
# Processing Record 24 of Set 6 | greeley
# Processing Record 25 of Set 6 | kieta
# Processing Record 26 of Set 6 | axim
# Processing Record 27 of Set 6 | vila velha
# Processing Record 28 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 29 of Set 6 | ranong
# Processing Record 30 of Set 6 | uitenhage
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | ahipara
# Processing Record 33 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 6 | georgiyevka
# Processing Record 35 of Set 6 | saldanha
# Processing Record 36 of Set 6 | iracoubo
# Processing Record 37 of Set 6 | arlit
# Processing Record 38 of Set 6 | lima
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | yeniseysk
# Processing Record 42 of Set 6 | zheleznodorozhnyy
# Processing Record 43 of Set 6 | edd
# Processing Record 44 of Set 6 | benxi
# Processing Record 45 of Set 6 | mtwara
# Processing Record 46 of Set 6 | kloulklubed
# Processing Record 47 of Set 6 | sangmelima
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | quatre cocos
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | simao
# Processing Record 2 of Set 7 | alekseyevsk
# Processing Record 3 of Set 7 | noumea
# Processing Record 4 of Set 7 | brigantine
# Processing Record 5 of Set 7 | marsaxlokk
# Processing Record 6 of Set 7 | mumford
# Processing Record 7 of Set 7 | san quintin
# Processing Record 8 of Set 7 | kenora
# Processing Record 9 of Set 7 | myitkyina
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | hamilton
# Processing Record 12 of Set 7 | wairoa
# Processing Record 13 of Set 7 | lompoc
# Processing Record 14 of Set 7 | ponta delgada
# Processing Record 15 of Set 7 | tarragona
# Processing Record 16 of Set 7 | ronne
# Processing Record 17 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 7 | taicheng
# Processing Record 19 of Set 7 | okha
# Processing Record 20 of Set 7 | santa vitoria do palmar
# Processing Record 21 of Set 7 | tera
# Processing Record 22 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 7 | luganville
# Processing Record 24 of Set 7 | bonthe
# Processing Record 25 of Set 7 | lasa
# Processing Record 26 of Set 7 | umba
# Processing Record 27 of Set 7 | kitui
# Processing Record 28 of Set 7 | tilichiki
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | kununurra
# Processing Record 31 of Set 7 | tigil
# Processing Record 32 of Set 7 | akureyri
# Processing Record 33 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 34 of Set 7 | tuatapere
# Processing Record 35 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 7 | tocopilla
# Processing Record 37 of Set 7 | tumba
# Processing Record 38 of Set 7 | griffith
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | mahebourg
# Processing Record 41 of Set 7 | abonnema
# Processing Record 42 of Set 7 | laguna
# Processing Record 43 of Set 7 | lyubeshiv
# City not found. Skipping...
# Processing Record 44 of Set 7 | turukhansk
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | provideniya
# Processing Record 47 of Set 7 | surt
# Processing Record 48 of Set 7 | pochutla
# Processing Record 49 of Set 7 | eureka
# Processing Record 50 of Set 7 | stornoway
# Processing Record 1 of Set 8 | kirakira
# Processing Record 2 of Set 8 | pringsewu
# Processing Record 3 of Set 8 | lalmohan
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | usuki
# Processing Record 6 of Set 8 | grenville
# Processing Record 7 of Set 8 | neftcala
# Processing Record 8 of Set 8 | makokou
# Processing Record 9 of Set 8 | san-pedro
# Processing Record 10 of Set 8 | poum
# Processing Record 11 of Set 8 | olinda
# Processing Record 12 of Set 8 | yar-sale
# Processing Record 13 of Set 8 | trojes
# Processing Record 14 of Set 8 | esperance
# Processing Record 15 of Set 8 | chabahar
# Processing Record 16 of Set 8 | inta
# Processing Record 17 of Set 8 | mookane
# Processing Record 18 of Set 8 | hay river
# Processing Record 19 of Set 8 | prince rupert
# Processing Record 20 of Set 8 | faya
# Processing Record 21 of Set 8 | sola
# Processing Record 22 of Set 8 | nishihara
# Processing Record 23 of Set 8 | nuevitas
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | marang
# Processing Record 26 of Set 8 | tawang
# Processing Record 27 of Set 8 | narsaq
# Processing Record 28 of Set 8 | evensk
# Processing Record 29 of Set 8 | shubarkuduk
# Processing Record 30 of Set 8 | cumpas
# Processing Record 31 of Set 8 | guerande
# Processing Record 32 of Set 8 | ouesso
# Processing Record 33 of Set 8 | kefamenanu
# Processing Record 34 of Set 8 | meadow lake
# Processing Record 35 of Set 8 | kaliganj
# Processing Record 36 of Set 8 | sao joao do piaui
# Processing Record 37 of Set 8 | skowhegan
# Processing Record 38 of Set 8 | paris
# Processing Record 39 of Set 8 | salaga
# Processing Record 40 of Set 8 | paita
# Processing Record 41 of Set 8 | talah
# City not found. Skipping...
# Processing Record 42 of Set 8 | surdulica
# Processing Record 43 of Set 8 | tabou
# Processing Record 44 of Set 8 | zhezkazgan
# Processing Record 45 of Set 8 | nanortalik
# Processing Record 46 of Set 8 | qui nhon
# Processing Record 47 of Set 8 | balykshi
# Processing Record 48 of Set 8 | price
# Processing Record 49 of Set 8 | berbera
# Processing Record 50 of Set 8 | shenjiamen
# Processing Record 1 of Set 9 | igrim
# Processing Record 2 of Set 9 | carauari
# Processing Record 3 of Set 9 | longyearbyen
# Processing Record 4 of Set 9 | laharpur
# Processing Record 5 of Set 9 | vostok
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | kavaratti
# Processing Record 8 of Set 9 | sumbe
# Processing Record 9 of Set 9 | norman wells
# Processing Record 10 of Set 9 | zhigansk
# Processing Record 11 of Set 9 | skagen
# Processing Record 12 of Set 9 | avila
# Processing Record 13 of Set 9 | gimli
# Processing Record 14 of Set 9 | chernyshevskiy
# Processing Record 15 of Set 9 | balkhash
# Processing Record 16 of Set 9 | usinsk
# Processing Record 17 of Set 9 | kontagora
# Processing Record 18 of Set 9 | juba
# Processing Record 19 of Set 9 | qaqortoq
# Processing Record 20 of Set 9 | tianpeng
# Processing Record 21 of Set 9 | ouahigouya
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | hobyo
# Processing Record 24 of Set 9 | sena madureira
# Processing Record 25 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 26 of Set 9 | conselice
# Processing Record 27 of Set 9 | karpathos
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | krumovgrad
# Processing Record 30 of Set 9 | luau
# Processing Record 31 of Set 9 | putina
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | black river
# Processing Record 34 of Set 9 | ginir
# Processing Record 35 of Set 9 | mandapam
# Processing Record 36 of Set 9 | louis trichardt
# Processing Record 37 of Set 9 | meulaboh
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | baijiantan
# Processing Record 40 of Set 9 | beira
# Processing Record 41 of Set 9 | parnarama
# Processing Record 42 of Set 9 | salinas
# Processing Record 43 of Set 9 | gizo
# Processing Record 44 of Set 9 | yanam
# Processing Record 45 of Set 9 | fare
# Processing Record 46 of Set 9 | victoria
# Processing Record 47 of Set 9 | etne
# Processing Record 48 of Set 9 | aksarka
# Processing Record 49 of Set 9 | alto araguaia
# Processing Record 50 of Set 9 | ugoofaaru
# Processing Record 1 of Set 10 | leogane
# Processing Record 2 of Set 10 | kiama
# Processing Record 3 of Set 10 | nikolayevsk-na-amure
# Processing Record 4 of Set 10 | rijnsburg
# Processing Record 5 of Set 10 | pyinmana
# Processing Record 6 of Set 10 | lata
# Processing Record 7 of Set 10 | daru
# Processing Record 8 of Set 10 | mackay
# Processing Record 9 of Set 10 | kuytun
# Processing Record 10 of Set 10 | beba
# Processing Record 11 of Set 10 | emerald
# Processing Record 12 of Set 10 | granby
# Processing Record 13 of Set 10 | avera
# Processing Record 14 of Set 10 | itaueira
# Processing Record 15 of Set 10 | tias
# Processing Record 16 of Set 10 | badamdar
# Processing Record 17 of Set 10 | gazli
# Processing Record 18 of Set 10 | nizhniy kuranakh
# Processing Record 19 of Set 10 | bilibino
# Processing Record 20 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 10 | nauta
# Processing Record 22 of Set 10 | xixiang
# Processing Record 23 of Set 10 | maneadero
# Processing Record 24 of Set 10 | galle
# Processing Record 25 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 10 | mogadishu
# Processing Record 27 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 10 | saint-francois
# Processing Record 29 of Set 10 | hinundayan
# Processing Record 30 of Set 10 | saryg-sep
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | abashiri
# Processing Record 33 of Set 10 | vardo
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | wajima
# Processing Record 36 of Set 10 | progreso
# Processing Record 37 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 10 | chateaudun
# Processing Record 39 of Set 10 | baisha
# Processing Record 40 of Set 10 | oda
# Processing Record 41 of Set 10 | yahotyn
# Processing Record 42 of Set 10 | kvareli
# Processing Record 43 of Set 10 | sibiti
# Processing Record 44 of Set 10 | tiznit
# Processing Record 45 of Set 10 | bambanglipuro
# Processing Record 46 of Set 10 | esso
# Processing Record 47 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 10 | lujan
# Processing Record 49 of Set 10 | hirado
# Processing Record 50 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 11 | urambo
# Processing Record 2 of Set 11 | nuuk
# Processing Record 3 of Set 11 | dovbysh
# Processing Record 4 of Set 11 | necochea
# Processing Record 5 of Set 11 | tucuman
# Processing Record 6 of Set 11 | basna
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | vadso
# Processing Record 10 of Set 11 | atambua
# Processing Record 11 of Set 11 | quelimane
# Processing Record 12 of Set 11 | santa
# Processing Record 13 of Set 11 | kaele
# Processing Record 14 of Set 11 | viedma
# Processing Record 15 of Set 11 | tyup
# Processing Record 16 of Set 11 | nemuro
# Processing Record 17 of Set 11 | xiongyue
# Processing Record 18 of Set 11 | krasnoselkup
# Processing Record 19 of Set 11 | alaca
# Processing Record 20 of Set 11 | kutum
# Processing Record 21 of Set 11 | zeya
# Processing Record 22 of Set 11 | batticaloa
# Processing Record 23 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 11 | sawtell
# Processing Record 25 of Set 11 | kudahuvadhoo
# Processing Record 26 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 11 | husavik
# Processing Record 28 of Set 11 | kermanshah
# Processing Record 29 of Set 11 | taganak
# Processing Record 30 of Set 11 | punta alta
# Processing Record 31 of Set 11 | sao joao da barra
# Processing Record 32 of Set 11 | lavrentiya
# Processing Record 33 of Set 11 | washougal
# Processing Record 34 of Set 11 | banswara
# Processing Record 35 of Set 11 | houston
# Processing Record 36 of Set 11 | karratha
# Processing Record 37 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 11 | umm lajj
# Processing Record 39 of Set 11 | khandyga
# Processing Record 40 of Set 11 | camacha
# Processing Record 41 of Set 11 | khromtau
# Processing Record 42 of Set 11 | abay
# Processing Record 43 of Set 11 | kuryk
# Processing Record 44 of Set 11 | at-bashi
# Processing Record 45 of Set 11 | ternate
# Processing Record 46 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 11 | larsnes
# Processing Record 48 of Set 11 | college
# Processing Record 49 of Set 11 | berlevag
# Processing Record 50 of Set 11 | abu dhabi
# Processing Record 1 of Set 12 | luancheng
# Processing Record 2 of Set 12 | mattru
# Processing Record 3 of Set 12 | muros
# Processing Record 4 of Set 12 | oussouye
# Processing Record 5 of Set 12 | bella vista
# Processing Record 6 of Set 12 | havre-saint-pierre
# Processing Record 7 of Set 12 | mbini
# Processing Record 8 of Set 12 | astakos
# Processing Record 9 of Set 12 | barra do garcas
# Processing Record 10 of Set 12 | angoche
# Processing Record 11 of Set 12 | purpe
# Processing Record 12 of Set 12 | bowen
# Processing Record 13 of Set 12 | diffa
# Processing Record 14 of Set 12 | bonavista
# Processing Record 15 of Set 12 | labuhan
# Processing Record 16 of Set 12 | iskateley
# Processing Record 17 of Set 12 | manaure
# Processing Record 18 of Set 12 | kjopsvik
# Processing Record 19 of Set 12 | adilabad
# Processing Record 20 of Set 12 | barcelos
# Processing Record 21 of Set 12 | iqaluit
# Processing Record 22 of Set 12 | dingle
# Processing Record 23 of Set 12 | rocha
# Processing Record 24 of Set 12 | nechi
# Processing Record 25 of Set 12 | geraldton
# Processing Record 26 of Set 12 | veraval
# Processing Record 27 of Set 12 | kiruna
# Processing Record 28 of Set 12 | vila franca do campo
# Processing Record 29 of Set 12 | thai binh
# Processing Record 30 of Set 12 | phon
# Processing Record 31 of Set 12 | chapais
# Processing Record 32 of Set 12 | sindor
# Processing Record 33 of Set 12 | miri
# Processing Record 34 of Set 12 | vanavara
# Processing Record 35 of Set 12 | dolores
# Processing Record 36 of Set 12 | la baule-escoublac
# Processing Record 37 of Set 12 | nouadhibou
# Processing Record 38 of Set 12 | dhadar
# Processing Record 39 of Set 12 | santa helena de goias
# Processing Record 40 of Set 12 | villazon
# Processing Record 41 of Set 12 | samana
# Processing Record 42 of Set 12 | tambopata
# Processing Record 43 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 12 | kabompo
# Processing Record 45 of Set 12 | saint anthony
# Processing Record 46 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 12 | royal tunbridge wells
# Processing Record 48 of Set 12 | yorkton
# Processing Record 49 of Set 12 | bilma
# Processing Record 50 of Set 12 | qingdao
# Processing Record 1 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 13 | manicore
# Processing Record 3 of Set 13 | belaya gora
# Processing Record 4 of Set 13 | kroya
# Processing Record 5 of Set 13 | tautira
# Processing Record 6 of Set 13 | hambantota
# Processing Record 7 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 8 of Set 13 | amahai
# Processing Record 9 of Set 13 | vao
# Processing Record 10 of Set 13 | jumla
# Processing Record 11 of Set 13 | verkhoyansk
# Processing Record 12 of Set 13 | ulaanbaatar
# Processing Record 13 of Set 13 | port lincoln
# Processing Record 14 of Set 13 | henties bay
# Processing Record 15 of Set 13 | opuwo
# Processing Record 16 of Set 13 | isabela
# Processing Record 17 of Set 13 | verkhnyaya toyma
# Processing Record 18 of Set 13 | dryden
# Processing Record 19 of Set 13 | newport
# Processing Record 20 of Set 13 | kasempa
# Processing Record 21 of Set 13 | tongren
# Processing Record 22 of Set 13 | pitsunda
# Processing Record 23 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 13 | taoudenni
# Processing Record 25 of Set 13 | airai
# Processing Record 26 of Set 13 | broken hill
# Processing Record 27 of Set 13 | tazovskiy
# Processing Record 28 of Set 13 | astoria
# Processing Record 29 of Set 13 | bayangol
# Processing Record 30 of Set 13 | ransang
# Processing Record 31 of Set 13 | sosua
# Processing Record 32 of Set 13 | sosva
# Processing Record 33 of Set 13 | ruse
# Processing Record 34 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 35 of Set 13 | svetlaya
# Processing Record 36 of Set 13 | buzmeyin
# Processing Record 37 of Set 13 | almaznyy
# Processing Record 38 of Set 13 | kalevala
# Processing Record 39 of Set 13 | bodmin
# Processing Record 40 of Set 13 | cangzhou
# Processing Record 41 of Set 13 | burns lake
# Processing Record 42 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 13 | setermoen
# Processing Record 44 of Set 13 | loikaw
# Processing Record 45 of Set 13 | yulara
# Processing Record 46 of Set 13 | mindelo
# Processing Record 47 of Set 13 | warmbad
# Processing Record 48 of Set 13 | sinnamary
# Processing Record 49 of Set 13 | itarema
# Processing Record 50 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 14 | corner brook
# Processing Record 2 of Set 14 | scottsbluff
# Processing Record 3 of Set 14 | sosnovo-ozerskoye
# Processing Record 4 of Set 14 | menongue
# Processing Record 5 of Set 14 | san joaquin
# Processing Record 6 of Set 14 | limulunga
# Processing Record 7 of Set 14 | amagasaki
# Processing Record 8 of Set 14 | jatiroto
# Processing Record 9 of Set 14 | westport
# Processing Record 10 of Set 14 | marsh harbour
# Processing Record 11 of Set 14 | comodoro rivadavia
# Processing Record 12 of Set 14 | namibe
# Processing Record 13 of Set 14 | willowmore
# Processing Record 14 of Set 14 | kihei
# Processing Record 15 of Set 14 | lipari
# Processing Record 16 of Set 14 | guicheng
# City not found. Skipping...
# Processing Record 17 of Set 14 | mulege
# Processing Record 18 of Set 14 | ambon
# Processing Record 19 of Set 14 | arzgir
# Processing Record 20 of Set 14 | bereda
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | coihaique
# Processing Record 23 of Set 14 | ust-kuyga
# Processing Record 24 of Set 14 | arman
# Processing Record 25 of Set 14 | kapoeta
# Processing Record 26 of Set 14 | high rock
# Processing Record 27 of Set 14 | shache
# Processing Record 28 of Set 14 | terney
# Processing Record 29 of Set 14 | rio grande
# Processing Record 30 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 14 | kargopol
# Processing Record 32 of Set 14 | sharqpur
# Processing Record 33 of Set 14 | roald
# Processing Record 34 of Set 14 | verkhnevilyuysk
# Processing Record 35 of Set 14 | borogontsy
# Processing Record 36 of Set 14 | gornopravdinsk
# Processing Record 37 of Set 14 | naze
# Processing Record 38 of Set 14 | richards bay
# Processing Record 39 of Set 14 | umm ruwabah
# City not found. Skipping...
# Processing Record 40 of Set 14 | shihezi
# Processing Record 41 of Set 14 | urucara
# Processing Record 42 of Set 14 | sattahip
# Processing Record 43 of Set 14 | kenai
# Processing Record 44 of Set 14 | altay
# Processing Record 45 of Set 14 | north bend
# Processing Record 46 of Set 14 | riyadh
# Processing Record 47 of Set 14 | aykhal
# Processing Record 48 of Set 14 | dauriya
# Processing Record 49 of Set 14 | maltahohe
# Processing Record 50 of Set 14 | locri
# Processing Record 1 of Set 15 | cairns
# Processing Record 2 of Set 15 | saint-jerome
# Processing Record 3 of Set 15 | kulhudhuffushi
# Processing Record 4 of Set 15 | baker city
# Processing Record 5 of Set 15 | santa marta
# Processing Record 6 of Set 15 | chikola
# Processing Record 7 of Set 15 | teguise
# Processing Record 8 of Set 15 | apartado
# Processing Record 9 of Set 15 | lethem
# Processing Record 10 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 15 | staraya russa
# Processing Record 12 of Set 15 | benghazi
# Processing Record 13 of Set 15 | khandbari
# Processing Record 14 of Set 15 | oranjemund
# Processing Record 15 of Set 15 | kailua
# Processing Record 16 of Set 15 | mount darwin
# Processing Record 17 of Set 15 | dawlatabad
# Processing Record 18 of Set 15 | osa
# Processing Record 19 of Set 15 | puli
# Processing Record 20 of Set 15 | los llanos de aridane
# Processing Record 21 of Set 15 | monte azul paulista
# Processing Record 22 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 23 of Set 15 | dali
# Processing Record 24 of Set 15 | chuy
# Processing Record 25 of Set 15 | berdigestyakh
# Processing Record 26 of Set 15 | abha
# Processing Record 27 of Set 15 | sur
# Processing Record 28 of Set 15 | kota belud
# Processing Record 29 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 15 | bam
# Processing Record 31 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 15 | orocue
# Processing Record 33 of Set 15 | nioaque
# Processing Record 34 of Set 15 | sao jose da coroa grande
# Processing Record 35 of Set 15 | parker
# Processing Record 36 of Set 15 | luderitz
# Processing Record 37 of Set 15 | dod ballapur
# Processing Record 38 of Set 15 | soyaux
# Processing Record 39 of Set 15 | takoradi
# Processing Record 40 of Set 15 | berezanka
# Processing Record 41 of Set 15 | urucui
# Processing Record 42 of Set 15 | deer lake
# Processing Record 43 of Set 15 | nyurba
# Processing Record 44 of Set 15 | palana
# Processing Record 45 of Set 15 | oktyabrskiy
# Processing Record 46 of Set 15 | balao
# Processing Record 47 of Set 15 | magadan
# Processing Record 48 of Set 15 | la sarre
# Processing Record 49 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 15 | biak
# Processing Record 1 of Set 16 | acari
# Processing Record 2 of Set 16 | diego de almagro
# Processing Record 3 of Set 16 | skelleftea
# Processing Record 4 of Set 16 | easthampton
# Processing Record 5 of Set 16 | xining
# Processing Record 6 of Set 16 | bryan
# Processing Record 7 of Set 16 | suao
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Katsuura      JP  35.1333  140.3000     79.63        81          44
# 1         Qaanaaq      GL  77.4840  -69.3632     31.87        84          82
# 2     Mount Holly      US  35.2982  -81.0159     85.10        63          75
# 3       Mount Isa      AU -20.7333  139.5000     71.37        64          75
# 4  Port Elizabeth      ZA -33.9180   25.5701     56.32        98           0
# 5       Hithadhoo      MV  -0.6000   73.0833     81.79        71         100
# 6        Kankakee      US  41.1500  -87.8667     81.82        61           0
# 7   Mar Del Plata      AR -38.0023  -57.5575     63.09        76          35
# 8          Avarua      CK -21.2078 -159.7750     78.85        73          40
# 9       Sistranda      NO  63.7256    8.8340     48.16        68          28
#
#    Wind Speed Current Description
# 0       15.30    scattered clouds
# 1        1.23       broken clouds
# 2       10.36       broken clouds
# 3        3.44       broken clouds
# 4        5.75           clear sky
# 5       15.48     overcast clouds
# 6        9.22           clear sky
# 7       11.99    scattered clouds
# 8       18.41    scattered clouds
# 9        3.94    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the DataFrame as a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
